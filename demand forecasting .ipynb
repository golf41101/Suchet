# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Python/Project/Forcast demand of product/Historical Product Demand.csv',parse_dates=['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Product_Code      1048575 non-null  object
#  1   Warehouse         1048575 non-null  object
#  2   Product_Category  1048575 non-null  object
#  3   Date              1037336 non-null  datetime64[ns]
#  4   Order_Demand      1048575 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 40.0+ MB

# %%
data_dt = data.sort_values('Date')

# %%
data_dt.head(20)
# Out:
#         Product_Code Warehouse Product_Category       Date Order_Demand
# 44799   Product_0965    Whse_A     Category_006 2011-01-08           2
# 72252   Product_1724    Whse_A     Category_003 2011-05-31         108
# 8431    Product_1521    Whse_S     Category_019 2011-06-24       85000
# 8432    Product_1521    Whse_S     Category_019 2011-06-24        7000
# 72669   Product_1507    Whse_C     Category_019 2011-09-02        1250
# 17249   Product_0608    Whse_C     Category_001 2011-09-27           5
# 17250   Product_1933    Whse_C     Category_001 2011-09-27          23
# 74615   Product_0875    Whse_C     Category_023 2011-09-30        5450
# 131426  Product_0125    Whse_S     Category_011 2011-10-20          (2)
# 131429  Product_0412    Whse_S     Category_007 2011-10-20          (2)
# 75193   Product_0642    Whse_C     Category_019 2011-10-31           3
# 121820  Product_0202    Whse_A     Category_007 2011-11-04        (100)
# ...

# %%
data_dt.tail(20)
# Out:
#         Product_Code Warehouse Product_Category Date Order_Demand
# 995448  Product_1424    Whse_A     Category_019  NaT        (200)
# 995449  Product_1443    Whse_A     Category_019  NaT       (2000)
# 995450  Product_1541    Whse_A     Category_019  NaT       (6800)
# 995451  Product_1422    Whse_A     Category_019  NaT       (1100)
# 995452  Product_1424    Whse_A     Category_019  NaT       (3600)
# 995453  Product_1284    Whse_A     Category_019  NaT        (400)
# 995454  Product_1388    Whse_A     Category_019  NaT        (200)
# 995455  Product_1416    Whse_A     Category_019  NaT        (200)
# 995456  Product_1419    Whse_A     Category_019  NaT        (200)
# 995457  Product_1420    Whse_A     Category_019  NaT        (200)
# 995458  Product_1422    Whse_A     Category_019  NaT        (800)
# 995459  Product_1423    Whse_A     Category_019  NaT       (1500)
# 995460  Product_1424    Whse_A     Category_019  NaT        (200)
# ...

# %%
data1 = data['Order_Demand']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Product_Code      1048575 non-null  object
#  1   Warehouse         1048575 non-null  object
#  2   Product_Category  1048575 non-null  object
#  3   Date              1037336 non-null  datetime64[ns]
#  4   Order_Demand      1048575 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 40.0+ MB

# %%
data.dtypes
# Out:
# Product_Code                object
# Warehouse                   object
# Product_Category            object
# Date                datetime64[ns]
# Order_Demand                object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Product_Code            0
# Warehouse               0
# Product_Category        0
# Date                11239
# Order_Demand            0
# dtype: int64

# %%
data.dtypes
# Out:
# Product_Code                object
# Warehouse                   object
# Product_Category            object
# Date                datetime64[ns]
# Order_Demand                object
# dtype: object

# %%
data['Order_Demand'] = data['Order_Demand'].str.replace('(','-')

# %%
data['Order_Demand'] = data['Order_Demand'].str.replace(')',"")

#Next step is to change the data type.
data['Order_Demand'] = data['Order_Demand'].astype('int64')

# %%
b = data[['Date','Order_Demand']]

# %%
data.dtypes
# Out:
# Product_Code                object
# Warehouse                   object
# Product_Category            object
# Date                datetime64[ns]
# Order_Demand                 int64
# dtype: object

# %%
data.tail(10)
# Out:
#          Product_Code Warehouse Product_Category       Date  Order_Demand
# 1048565  Product_0332    Whse_J     Category_021 2016-11-11             4
# 1048566  Product_0308    Whse_J     Category_024 2016-11-02             8
# 1048567  Product_1759    Whse_J     Category_001 2016-07-07             1
# 1048568  Product_1759    Whse_J     Category_001 2016-08-17             1
# 1048569  Product_1759    Whse_J     Category_001 2016-11-10             2
# 1048570  Product_1791    Whse_J     Category_006 2016-04-27          1000
# 1048571  Product_1974    Whse_J     Category_006 2016-04-27             1
# 1048572  Product_1787    Whse_J     Category_006 2016-04-28          2500
# 1048573  Product_0901    Whse_J     Category_023 2016-10-07            50
# 1048574  Product_0704    Whse_J     Category_001 2016-06-27             4

# %%
b.dtypes
# Out:
# Date            datetime64[ns]
# Order_Demand             int64
# dtype: object

# %%
data.dropna(axis=0, inplace=True) #remove rows with nan value
data.reset_index(drop=True)
# Out:
#          Product_Code Warehouse Product_Category       Date  Order_Demand
# 0        Product_0993    Whse_J     Category_028 2012-07-27           100
# 1        Product_0979    Whse_J     Category_028 2012-01-19           500
# 2        Product_0979    Whse_J     Category_028 2012-02-03           500
# 3        Product_0979    Whse_J     Category_028 2012-02-09           500
# 4        Product_0979    Whse_J     Category_028 2012-03-02           500
# ...               ...       ...              ...        ...           ...
# 1037331  Product_1791    Whse_J     Category_006 2016-04-27          1000
# 1037332  Product_1974    Whse_J     Category_006 2016-04-27             1
# 1037333  Product_1787    Whse_J     Category_006 2016-04-28          2500
# 1037334  Product_0901    Whse_J     Category_023 2016-10-07            50
# 1037335  Product_0704    Whse_J     Category_001 2016-06-27             4
#
# [1037336 rows x 5 columns]

# %%
import seaborn as sns

# %%
b.nlargest(15,columns='Order_Demand')
# Out:
#              Date  Order_Demand
# 20892  2012-06-11       4000000
# 20477  2012-07-05       3000000
# 72638  2012-02-06       3000000
# 222266 2013-06-14       3000000
# 258396 2013-11-11       2560000
# 108179 2012-11-26       2500000
# 659046 2015-03-13       2500000
# 659050 2015-05-19       2500000
# 659055 2015-10-09       2500000
# 871363 2016-07-29       2500000
# 908536 2016-01-12       2300000
# 438942 2014-01-24       2199000
# 20881  2012-01-05       2000000
# 20886  2012-03-01       2000000
# 20890  2012-05-10       2000000

# %%
#plt.figure(figsize=(15, 8))
#g=sns.barplot(x='Product_Category',data=data)
#plt.xticks(rotation=90)

# %%
# ?data.sort_values

# %%
data_sorted= data.sort_values('Product_Category',ascending=False)

# %%
data_sorted.head(5)
# Out:
#         Product_Code Warehouse Product_Category       Date  Order_Demand
# 681414  Product_1362    Whse_J     Category_033 2015-07-27         10000
# 217130  Product_1361    Whse_J     Category_033 2013-01-09         10000
# 250573  Product_1361    Whse_J     Category_033 2013-03-29         10000
# 250572  Product_1361    Whse_J     Category_033 2013-03-15         10000
# 499488  Product_1361    Whse_J     Category_033 2014-10-20         10000

# %%
data.groupby(['Product_Category']).sum().sort_values(['Order_Demand'], axis=0, ascending=False).head(10)
# Out:
#                   Order_Demand
# Product_Category
# Category_019        4219806665
# Category_006         401649668
# Category_005         198361890
# Category_007         127725843
# Category_028          47276346
# Category_033          42370000
# Category_030          39781355
# Category_032           4445960
# Category_021           4349008
# Category_009           3608993

# %%
data_sorted_c = data.groupby(['Product_Category']).count().sort_values(['Order_Demand'], axis=0, ascending=False)

# %%
data_sorted_s = data.groupby(['Product_Category']).sum().sort_values(['Order_Demand'], axis=0, ascending=False)

# %%
data_sorted_s.head(5)
# Out:
#                   Order_Demand
# Product_Category
# Category_019        4219806665
# Category_006         401649668
# Category_005         198361890
# Category_007         127725843
# Category_028          47276346

# %%
data_cc = data_sorted_c.reset_index()

# %%
data_cc = data_cc.head(10)

# %%
data_cc
# Out:
#   Product_Category  Product_Code  Warehouse    Date  Order_Demand
# 0     Category_019        470266     470266  470266        470266
# 1     Category_005        101627     101627  101627        101627
# 2     Category_001         97787      97787   97787         97787
# 3     Category_007         82402      82402   82402         82402
# 4     Category_021         52008      52008   52008         52008
# 5     Category_006         35552      35552   35552         35552
# 6     Category_028         31012      31012   31012         31012
# 7     Category_011         23208      23208   23208         23208
# 8     Category_015         22954      22954   22954         22954
# 9     Category_024         20885      20885   20885         20885

# %%
data_cc.plot(x='Product_Category',fontsize=15,y='Order_Demand',figsize=(19,9),color='black',kind='bar')
plt.grid(True)
plt.title('Count of Product',size=25)
plt.ylabel("Order",size=15)
plt.xlabel("Category",size=15)
plt.show()

# %%
data_ss = data_sorted_s.reset_index()

# %%
data_ss.head(10)
# Out:
#   Product_Category  Order_Demand
# 0     Category_019    4219806665
# 1     Category_006     401649668
# 2     Category_005     198361890
# 3     Category_007     127725843
# 4     Category_028      47276346
# 5     Category_033      42370000
# 6     Category_030      39781355
# 7     Category_032       4445960
# 8     Category_021       4349008
# 9     Category_009       3608993

# %%
plt.figure(figsize=(15, 12))
plt.title('Count product')
g=sns.barplot(x=data_cc['Product_Category'],y=data_cc['Order_Demand'], data=data_cc)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plt.title('Sum product')
g=sns.barplot(x=data_ss['Product_Category'],y=data_ss['Order_Demand'], data=data_ss)
plt.ylabel("Order(1e9=1x(10**9)",size=15)
plt.xlabel("Category",size=15)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
from matplotlib.ticker import ScalarFormatter

# %%
data_ss.plot(x='Product_Category',y='Order_Demand',figsize=(15,12),color='navy',fontsize=12,kind='bar')
plt.grid(True)
plt.title('Sum of Product',size=25)
plt.ylabel("Order(1e9=1x(10**9)",size=15)
plt.xlabel("Category",size=15)
plt.show()

# %%
data.plot(x='Date',figsize=(16,9),color='r')
plt.grid(True)
plt.show()

# %%
data_sorted_pd = data.groupby(['Product_Category']).count().sort_values(['Order_Demand'], axis=0, ascending=False)

# %%
data_sorted_pd_s = data.groupby(['Product_Code']).sum().sort_values(['Order_Demand'], axis=0, ascending=False)

# %%
data.sort_values(['Order_Demand'], axis=0, ascending=True).head(25)
# Out:
#          Product_Code Warehouse Product_Category       Date  Order_Demand
# 585144   Product_1241    Whse_J     Category_019 2014-03-27       -999000
# 182061   Product_1359    Whse_J     Category_019 2012-09-13       -500000
# 999608   Product_1817    Whse_S     Category_006 2016-06-06       -472500
# 131405   Product_0366    Whse_S     Category_030 2011-12-23       -349500
# 146980   Product_1295    Whse_J     Category_019 2012-03-06       -322500
# 568159   Product_1245    Whse_C     Category_019 2014-10-14       -300000
# 568158   Product_1355    Whse_C     Category_019 2014-10-10       -295000
# 130697   Product_0071    Whse_C     Category_019 2012-11-12       -250000
# 410611   Product_1461    Whse_J     Category_019 2013-09-24       -249950
# 1000967  Product_1157    Whse_J     Category_006 2016-06-27       -240000
# 999609   Product_1825    Whse_S     Category_006 2016-06-06       -225000
# 1002994  Product_1267    Whse_J     Category_019 2016-05-10       -200000
# ...

# %%
#find negative value in order_demand , it means return the orders
data_neg = data.loc[data['Order_Demand'] <0]

# %%
data_neg.groupby(['Warehouse']).size()
# Out:
# Warehouse
# Whse_A    1825
# Whse_C     117
# Whse_J    3555
# Whse_S     402
# dtype: int64

# %%
data_neg.groupby(['Warehouse']).count()
# Out:
#            Product_Code  Product_Category  Date  Order_Demand
# Warehouse
# Whse_A             1825              1825  1825          1825
# Whse_C              117               117   117           117
# Whse_J             3555              3555  3555          3555
# Whse_S              402               402   402           402

# %%
checkneg = data_neg[data_neg['Warehouse'].isin(['Whse_J'])]

# %%
checkneg.sort_values(['Order_Demand'], axis=0, ascending=True)
# Out:
#          Product_Code Warehouse Product_Category       Date  Order_Demand
# 585144   Product_1241    Whse_J     Category_019 2014-03-27       -999000
# 182061   Product_1359    Whse_J     Category_019 2012-09-13       -500000
# 146980   Product_1295    Whse_J     Category_019 2012-03-06       -322500
# 410611   Product_1461    Whse_J     Category_019 2013-09-24       -249950
# 1000967  Product_1157    Whse_J     Category_006 2016-06-27       -240000
# ...               ...       ...              ...        ...           ...
# 579881   Product_0826    Whse_J     Category_008 2014-09-12            -1
# 185708   Product_0721    Whse_J     Category_001 2012-11-12            -1
# 826932   Product_1865    Whse_J     Category_001 2015-09-17            -1
# 1022945  Product_0346    Whse_J     Category_021 2016-01-14            -1
# 410376   Product_1025    Whse_J     Category_007 2013-10-09            -1
#
# [3555 rows x 5 columns]

# %%
data_neg_plt = data_neg.groupby(['Product_Category']).count().sort_values(['Order_Demand'], axis=0, ascending=False).head(10)

# %%
data_neg_plt = data_neg_plt.reset_index()

# %%
data_neg_plt
# Out:
#   Product_Category  Product_Code  Warehouse  Date  Order_Demand
# 0     Category_019          1412       1412  1412          1412
# 1     Category_007           771        771   771           771
# 2     Category_021           655        655   655           655
# 3     Category_001           590        590   590           590
# 4     Category_009           346        346   346           346
# 5     Category_015           334        334   334           334
# 6     Category_024           327        327   327           327
# 7     Category_005           292        292   292           292
# 8     Category_028           236        236   236           236
# 9     Category_006           163        163   163           163

# %%
plt.figure(figsize=(19, 15))
plt.title('Order Product(Category) by Warehouse')
g=sns.barplot(x=data['Product_Category'],y=data['Order_Demand'],hue=data['Warehouse'], data=data)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(19, 15))
plt.title('Top 10 times of Order Product(Category)')
g=sns.barplot(x=data_cc['Product_Category'],y=data_cc['Order_Demand'], data=data_cc)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# find Warehouse return order by count
data_neg.groupby(['Warehouse']).count().sort_values(['Order_Demand'], axis=0, ascending=False)
# Out:
#            Product_Code  Product_Category  Date  Order_Demand
# Warehouse
# Whse_J             3555              3555  3555          3555
# Whse_A             1825              1825  1825          1825
# Whse_S              402               402   402           402
# Whse_C              117               117   117           117

# %%
# find Warehouse return order by sum
data_neg.groupby(['Warehouse']).sum().sort_values(['Order_Demand'], axis=0, ascending=True)
# Out:
#            Order_Demand
# Warehouse
# Whse_J         -9339339
# Whse_A         -2309874
# Whse_S         -1898541
# Whse_C         -1613096

# %%
# find Warehouse return order by mean
data_neg.groupby(['Warehouse']).mean().sort_values(['Order_Demand'], axis=0, ascending=True)
# Out:
#            Order_Demand
# Warehouse
# Whse_C    -13787.145299
# Whse_S     -4722.738806
# Whse_J     -2627.099578
# Whse_A     -1265.684384

# %%
data.groupby(['Warehouse']).size()
# Out:
# Warehouse
# Whse_A    142335
# Whse_C     42354
# Whse_J    764447
# Whse_S     88200
# dtype: int64

# %%
#find ratio of return order/order, count/sum
print('ratio of return order by Warehouse') 
print('Whse_A ',1825/142335)
print('Whse_C ',117/42354)
print('Whse_J ',3555/764447)
print('Whse_S ',402/88200)
# Out:
# ratio of return order by Warehouse
# Whse_A  0.012821863912600555
# Whse_C  0.0027624309392265192
# Whse_J  0.004650420500047747
# Whse_S  0.0045578231292517

# %%
#Whase_A is the most return order

# %%
data_plot_n = data_neg.sort_values(['Order_Demand'], axis=0, ascending=True)

# %%
data_plot_n
# Out:
#         Product_Code Warehouse Product_Category       Date  Order_Demand
# 585144  Product_1241    Whse_J     Category_019 2014-03-27       -999000
# 182061  Product_1359    Whse_J     Category_019 2012-09-13       -500000
# 999608  Product_1817    Whse_S     Category_006 2016-06-06       -472500
# 131405  Product_0366    Whse_S     Category_030 2011-12-23       -349500
# 146980  Product_1295    Whse_J     Category_019 2012-03-06       -322500
# ...              ...       ...              ...        ...           ...
# 780773  Product_2093    Whse_A     Category_009 2015-02-09            -1
# 780533  Product_0394    Whse_A     Category_007 2015-06-03            -1
# 780516  Product_0643    Whse_A     Category_028 2015-11-30            -1
# 344990  Product_1168    Whse_A     Category_007 2013-12-11            -1
# 112290  Product_2169    Whse_A     Category_024 2012-08-09            -1
#
# [5899 rows x 5 columns]

# %%
plt.figure(figsize=(15, 12))
plt.title('Top 10 times of return Product(Category)')
g=sns.barplot(x=data_plot_n['Product_Category'],y=data_plot_n['Order_Demand'], data=data_plot_n, hue =data_plot_n['Warehouse'])
plt.xticks(rotation=90)
plt.ylabel("return order")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plt.title('Top 10 times of return Product(Category)')
g=sns.barplot(x=data_neg_plt['Product_Category'],y=data_neg_plt['Order_Demand'], data=data_neg_plt)
plt.xticks(rotation=90)
plt.ylabel("return order")
plt.grid(True)
plt.show()

# %%
data_sorted_pd_1 = data.groupby(['Product_Category','Product_Code']).count()

# %%
data_sorted_pd_1 = data_sorted_pd_1.sort_values(['Order_Demand'], axis=0, ascending=False)

# %%
data_sorted_pd_1
# Out:
#                                Warehouse   Date  Order_Demand
# Product_Category Product_Code
# Category_019     Product_1359      16936  16936         16936
#                  Product_1295      10575  10575         10575
#                  Product_1378       9770   9770          9770
# Category_001     Product_0620       9428   9428          9428
# Category_019     Product_1286       8888   8888          8888
# ...                                  ...    ...           ...
# Category_021     Product_1698          2      2             2
# Category_009     Product_2099          1      1             1
# Category_021     Product_1703          1      1             1
#                  Product_0853          1      1             1
# Category_012     Product_0465          1      1             1
#
# [2160 rows x 3 columns]

# %%
data_sorted_pd_1['Order_Demand'].sum()
# Out:
# 1037336

# %%
len(data_sorted_pd_1['Order_Demand'])
# Out:
# 2160

# %%
data_sorted_pd_1['Percent'] = ((data_sorted_pd_1['Order_Demand']/data_sorted_pd_1['Order_Demand'].sum())*100).round(2)

# %%
data_sorted_pd_1.dtypes
# Out:
# Warehouse         int64
# Date              int64
# Order_Demand      int64
# Percent         float64
# dtype: object

# %%
data_sorted_pd_2= data_sorted_pd_1.nlargest(10,'Order_Demand')

# %%
data_sorted_pd_2
# Out:
#                                Warehouse   Date  Order_Demand  Percent
# Product_Category Product_Code
# Category_019     Product_1359      16936  16936         16936     1.63
#                  Product_1295      10575  10575         10575     1.02
#                  Product_1378       9770   9770          9770     0.94
# Category_001     Product_0620       9428   9428          9428     0.91
# Category_019     Product_1286       8888   8888          8888     0.86
#                  Product_1382       8619   8619          8619     0.83
#                  Product_1453       8503   8503          8503     0.82
#                  Product_1294       8384   8384          8384     0.81
#                  Product_1377       7872   7872          7872     0.76
#                  Product_1287       7829   7829          7829     0.75

# %%
data_sorted_pd_2= data_sorted_pd_2.reset_index()

# %%
# ?data_sorted_pd_2.drop([['Warehouse','Date']],axis=0)
# Out:
# Object `data_sorted_pd_2.drop([['Warehouse','Date']],axis=0)` not found.

# %%
data_sorted_pd_2 = data_sorted_pd_2.drop(columns=['Warehouse','Date'],axis=0)

# %%
data_sorted_pd_2.sum()
# Out:
# Product_Category    Category_019Category_019Category_019Category_0...
# Product_Code        Product_1359Product_1295Product_1378Product_06...
# Order_Demand                                                    96804
# Percent                                                          9.33
# dtype: object

# %%
data_s3 = data[data['Product'].isin(['Whse_J'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-42f7c750d8c1> in <module>
# ...

# %%
data_sorted_pd_2

# %%
plt.figure(figsize=(15, 12))
plt.title('Summmm product')
g=sns.barplot(x=data_sorted_pd_2['Product_Code'],y=data_sorted_pd_2['Percent'],hue=data_sorted_pd_2['Product_Category'],data=data_sorted_pd_2)
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plt.title('Summmm product')
g=sns.barplot(x=data_sorted_pd_2['Product_Category'],y=data_sorted_pd_2['Percent'],hue=data_sorted_pd_2['Product_Code'],data=data_sorted_pd_2,color='y')
plt.grid(True)
plt.show()

# %%
#time series
